# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from fbprophet import Prophet

# %matplotlib inline


df = pd.read_excel("/Users/seojunebeom/Desktop/대학교/2022 1학기/기계학습/전처리-WTI유가/4.xls")

# %%
#fbprophet 사용 형식에 맞추기

df_tmp = pd.DataFrame({"ds":df["날짜"], "y":df["종가"]})
df_target = df_tmp[:-1]	# 끝에 NaN 값을 제거함

df = df_target.copy()
df["ds"] = pd.to_datetime(df_target["ds"], format="%b %d, %Y")

# .info()로 확인하면 object이기 때문에 숫자로 바꿔줌
df["y"] = df["y"].astype("float")

# %%
#prophet 적용 & 예측

m = Prophet(yearly_seasonality=True, daily_seasonality=True)
m.fit(df);

future = m.make_future_dataframe(periods=30)
forecast = m.predict(future)
forecast[["ds", "yhat", "yhat_lower", "yhat_upper"]].tail()
# Out:
# /Users/seojunebeom/opt/anaconda3/lib/python3.9/site-packages/fbprophet/forecaster.py:891: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)
# Initial log joint probability = -168.512
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       5839.46      0.330076       1285.16           1           1      125
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199       6023.29     0.0144585       1968.68      0.4095           1      239
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      299       6160.76     0.0173088       674.423           1           1      364
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      399       6212.72    0.00354159       110.784           1           1      480
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      499       6232.74     0.0547182        374.05           1           1      592
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      599       6260.32     0.0147868       431.005           1           1      710
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      699       6271.25     0.0170772       396.898           1           1      827
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      799       6278.53   0.000638957       139.552       0.857       0.857      951
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      899       6291.19      0.135091       1477.96      0.1794           1     1075
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      999       6300.82   0.000392812       123.351           1           1     1185
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1099       6304.05   0.000481967       132.734           1           1     1305
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1133       6305.16   4.97004e-05       116.265   2.315e-07       0.001     1392  LS failed, Hessian reset
#     1171       6306.71   4.95051e-05       125.233   2.622e-07       0.001     1475  LS failed, Hessian reset
#     1199       6307.18   0.000102697       103.941      0.9891      0.9891     1512
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1212       6307.29   0.000237669       183.984   2.097e-06       0.001     1562  LS failed, Hessian reset
#     1299       6307.98    0.00259087       112.414      0.3741           1     1679
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1364       6314.56   7.31905e-05       192.402   4.077e-07       0.001     1824  LS failed, Hessian reset
#     1399       6324.76   0.000688819       174.067           1           1     1875
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1499       6329.24   0.000876679        71.651       4.173      0.4173     1991
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1523       6329.91   0.000235703       363.639   1.055e-06       0.001     2065  LS failed, Hessian reset
#     1599        6330.8   0.000185771        76.825      0.9234      0.9234     2150
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1699       6332.72   8.20532e-05       190.952         0.6         0.6     2272
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1799       6334.08   0.000275176       91.3527           1           1     2390
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1899        6336.9    0.00745562       491.958        9.73       0.973     2513
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1974       6338.26   6.68591e-05       136.435   8.812e-07       0.001     2643  LS failed, Hessian reset
#     1999       6338.31   0.000286198       73.1298      0.8337      0.8337     2672
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2022        6338.4   5.54327e-05       159.037   3.921e-07       0.001     2736  LS failed, Hessian reset
#     2069       6338.47   3.75053e-06       68.3408   6.245e-08       0.001     2844  LS failed, Hessian reset
#     2099       6338.48   9.13485e-06       57.4685           1           1     2879
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2114       6338.48   3.54631e-07       61.0441      0.3122           1     2899
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# /Users/seojunebeom/opt/anaconda3/lib/python3.9/site-packages/fbprophet/forecaster.py:891: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)
# /Users/seojunebeom/opt/anaconda3/lib/python3.9/site-packages/fbprophet/forecaster.py:891: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)
#              ds       yhat  yhat_lower  yhat_upper
# 2994 2022-06-17  96.544695   87.422675  106.206278
# 2995 2022-06-18  95.894446   85.510196  105.215588
# 2996 2022-06-19  97.115684   87.430489  106.806568
# 2997 2022-06-20  96.834965   87.921163  106.362344
# 2998 2022-06-21  97.174491   87.103805  106.666654

# %%
#시각화

plt.figure(figsize=(12,6))
plt.plot(df["ds"], df["y"], label="real")
plt.grid(True)
plt.show()

# %%
m.plot_components(forecast);
# Out:
# /Users/seojunebeom/opt/anaconda3/lib/python3.9/site-packages/fbprophet/forecaster.py:891: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)
# /Users/seojunebeom/opt/anaconda3/lib/python3.9/site-packages/fbprophet/forecaster.py:891: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)
# /Users/seojunebeom/opt/anaconda3/lib/python3.9/site-packages/fbprophet/forecaster.py:891: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)

# %%
m = Prophet(yearly_seasonality=True, daily_seasonality=True)
m.fit(df);

future = m.make_future_dataframe(periods=30)
forecast = m.predict(future)
forecast[["ds", "yhat", "yhat_lower", "yhat_upper"]].tail()
# Out:
# /Users/seojunebeom/opt/anaconda3/lib/python3.9/site-packages/fbprophet/forecaster.py:891: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)
# Initial log joint probability = -168.512
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       5839.46      0.330076       1285.16           1           1      125
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199       6023.29     0.0144585       1968.68      0.4095           1      239
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      299       6160.76     0.0173088       674.423           1           1      364
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      399       6212.72    0.00354159       110.784           1           1      480
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      499       6232.74     0.0547182        374.05           1           1      592
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      599       6260.32     0.0147868       431.005           1           1      710
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      699       6271.25     0.0170772       396.898           1           1      827
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      799       6278.53   0.000638957       139.552       0.857       0.857      951
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      899       6291.19      0.135091       1477.96      0.1794           1     1075
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      999       6300.82   0.000392812       123.351           1           1     1185
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1099       6304.05   0.000481967       132.734           1           1     1305
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1133       6305.16   4.97004e-05       116.265   2.315e-07       0.001     1392  LS failed, Hessian reset
#     1171       6306.71   4.95051e-05       125.233   2.622e-07       0.001     1475  LS failed, Hessian reset
#     1199       6307.18   0.000102697       103.941      0.9891      0.9891     1512
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1212       6307.29   0.000237669       183.984   2.097e-06       0.001     1562  LS failed, Hessian reset
#     1299       6307.98    0.00259087       112.414      0.3741           1     1679
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1364       6314.56   7.31905e-05       192.402   4.077e-07       0.001     1824  LS failed, Hessian reset
#     1399       6324.76   0.000688819       174.067           1           1     1875
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1499       6329.24   0.000876679        71.651       4.173      0.4173     1991
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1523       6329.91   0.000235703       363.639   1.055e-06       0.001     2065  LS failed, Hessian reset
#     1599        6330.8   0.000185771        76.825      0.9234      0.9234     2150
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1699       6332.72   8.20532e-05       190.952         0.6         0.6     2272
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1799       6334.08   0.000275176       91.3527           1           1     2390
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1899        6336.9    0.00745562       491.958        9.73       0.973     2513
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1974       6338.26   6.68591e-05       136.435   8.812e-07       0.001     2643  LS failed, Hessian reset
#     1999       6338.31   0.000286198       73.1298      0.8337      0.8337     2672
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2022        6338.4   5.54327e-05       159.037   3.921e-07       0.001     2736  LS failed, Hessian reset
#     2069       6338.47   3.75053e-06       68.3408   6.245e-08       0.001     2844  LS failed, Hessian reset
#     2099       6338.48   9.13485e-06       57.4685           1           1     2879
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2114       6338.48   3.54631e-07       61.0441      0.3122           1     2899
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# /Users/seojunebeom/opt/anaconda3/lib/python3.9/site-packages/fbprophet/forecaster.py:891: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)
# /Users/seojunebeom/opt/anaconda3/lib/python3.9/site-packages/fbprophet/forecaster.py:891: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)
#              ds       yhat  yhat_lower  yhat_upper
# 2994 2022-06-17  96.544695   87.012290  105.672791
# 2995 2022-06-18  95.894446   86.624367  105.194933
# 2996 2022-06-19  97.115684   87.331605  107.081142
# 2997 2022-06-20  96.834965   87.553936  106.589356
# 2998 2022-06-21  97.174491   87.704030  107.159296

# %%
# 예측 그래프
m.plot(forecast);
# component 별 그래프 (이미지 생략)
m.plot_components(forecast);
# Out:
# /Users/seojunebeom/opt/anaconda3/lib/python3.9/site-packages/fbprophet/forecaster.py:891: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)
# /Users/seojunebeom/opt/anaconda3/lib/python3.9/site-packages/fbprophet/forecaster.py:891: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)
# /Users/seojunebeom/opt/anaconda3/lib/python3.9/site-packages/fbprophet/forecaster.py:891: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)

# %%
plt.figure(figsize=(12,6))

plt.plot(forecast["ds"], forecast["yhat"], label="forecast")
plt.grid(True)
plt.legend()
plt.show()
