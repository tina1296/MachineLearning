# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#df1 = pd.read_csv("/Users/tina/Desktop/기계/R 3종 데이터/S&P 500/1번데이터.csv")
#df2 = pd.read_csv("/Users/tina/Desktop/기계/S&P/2번데이터.csv")
df3 = pd.read_csv("/Users/tina/Desktop/기계/S&P/3번데이터.csv")
#df4 = pd.read_csv("/Users/tina/Desktop/기계/S&P/4번데이터.csv")

# %%
df1
# Out:
#                  날짜     종가     오픈     고가     저가 거래량    변동 %
# 0     1989년 12월 29일  353.4  350.7  353.4  350.7   -   0.77%
# 1     1989년 12월 28일  350.7  348.8  350.7  348.8   -   0.54%
# 2     1989년 12월 27일  348.8  346.8  349.1  346.8   -   0.58%
# 3     1989년 12월 26일  346.8  347.4  347.9  346.5   -  -0.17%
# 4     1989년 12월 22일  347.4  344.8  347.5  344.8   -   0.75%
# ...             ...    ...    ...    ...    ...  ..     ...
# 2526  1980년 01월 07일  106.8  106.8  107.8  105.8   -   0.28%
# 2527  1980년 01월 04일  106.5  106.5  107.1  105.1   -   1.24%
# 2528  1980년 01월 03일  105.2  105.2  106.1  103.3   -  -0.57%
# 2529  1980년 01월 02일  105.8  105.8  108.4  105.3   -  -1.95%
# 2530  1980년 01월 01일  107.9  107.9  107.9  107.9   -   0.00%
#
# [2531 rows x 7 columns]

# %%
df1.to_excel("/Users/tina/Desktop/기계/R 3종 데이터/S&P 500/1번데이터.xlsx")

# %%
#df2.to_excel("/Users/tina/Desktop/기계/R 3종 데이터/S&P 500/2번데이터.xlsx")
df3.to_excel("/Users/tina/Desktop/기계/R 3종 데이터/S&P 500/3번데이터2.xlsx")
#df4.to_excel("/Users/tina/Desktop/기계/R 3종 데이터/S&P 500/4번데이터.xlsx")

# %%
df1 = pd.read_excel("/Users/tina/Desktop/기계/R 3종 데이터/S&P 500/1번데이터.xlsx", index_col=0)
df2 = pd.read_excel("/Users/tina/Desktop/기계/R 3종 데이터/S&P 500/2번데이터.xlsx", index_col=0)
df3 = pd.read_excel("/Users/tina/Desktop/기계/R 3종 데이터/S&P 500/3번데이터.xlsx", index_col=0)
df4 = pd.read_excel("/Users/tina/Desktop/기계/R 3종 데이터/S&P 500/4번데이터.xlsx", index_col=0)

# %%
df3
# Out:
#              날짜     종가     오픈     고가     저가 거래량    변동 %
# 0    1989-12-29  353.4  350.7  353.4  350.7   -   0.77%
# 1    1989-12-28  350.7  348.8  350.7  348.8   -   0.54%
# 2    1989-12-27  348.8  346.8  349.1  346.8   -   0.58%
# 3    1989-12-26  346.8  347.4  347.9  346.5   -  -0.17%
# 4    1989-12-22  347.4  344.8  347.5  344.8   -   0.75%
# ...         ...    ...    ...    ...    ...  ..     ...
# 2526 1980-01-07  106.8  106.8  107.8  105.8   -   0.28%
# 2527 1980-01-04  106.5  106.5  107.1  105.1   -   1.24%
# 2528 1980-01-03  105.2  105.2  106.1  103.3   -  -0.57%
# 2529 1980-01-02  105.8  105.8  108.4  105.3   -  -1.95%
# 2530 1980-01-01  107.9  107.9  107.9  107.9   -   0.00%
#
# [2531 rows x 7 columns]

# %%
plt.figure(figsize=(16, 9))
sns.lineplot(y=df1['종가'], x=df1['날짜'])
plt.xlabel('time')
plt.ylabel('price')
# Out:
# Text(0, 0.5, 'price')

# %%
plt.figure(figsize=(16, 9))
sns.lineplot(y=df3['종가'], x=df3['날짜'])
plt.xlabel('time')
plt.ylabel('price')
# Out:
# Text(0, 0.5, 'price')
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 45380 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 50900 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 51068 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 45380 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 50900 missing from current font.
#   font.set_text(s, 0, flags=flags)
# ...

# %%
df_total=pd.concat([df1, df2,df3,df4])

# %%
df_total
# Out:
#                        날짜        종가        오픈        고가        저가 거래량    변동 %
# 0     1989-12-29 00:00:00     353.4     350.7     353.4     350.7   -   0.77%
# 1     1989-12-28 00:00:00     350.7     348.8     350.7     348.8   -   0.54%
# 2     1989-12-27 00:00:00     348.8     346.8     349.1     346.8   -   0.58%
# 3     1989-12-26 00:00:00     346.8     347.4     347.9     346.5   -  -0.17%
# 4     1989-12-22 00:00:00     347.4     344.8     347.5     344.8   -   0.75%
# ...                   ...       ...       ...       ...       ...  ..     ...
# 2862        2011년 01월 06일  1,273.85  1,276.29  1,278.17  1,270.43   -  -0.21%
# 2863        2011년 01월 05일  1,276.56  1,268.78  1,277.63  1,265.36   -   0.50%
# 2864        2011년 01월 04일  1,270.20  1,272.95  1,274.12  1,262.66   -  -0.13%
# 2865        2011년 01월 03일  1,271.87  1,257.62  1,276.17  1,257.62   -   1.13%
# 2866        2010년 12월 31일  1,257.64  1,256.76  1,259.34  1,254.19   -  -0.02%
#
# [10694 rows x 7 columns]

# %%
df1_1 = df1[['날짜', '종가','오픈','고가','저가']]
df1_1
# Out:
#              날짜     종가     오픈     고가     저가
# 2530 1980-01-01  107.9  107.9  107.9  107.9
# 2529 1980-01-02  105.8  105.8  108.4  105.3
# 2528 1980-01-03  105.2  105.2  106.1  103.3
# 2527 1980-01-04  106.5  106.5  107.1  105.1
# 2526 1980-01-07  106.8  106.8  107.8  105.8
# ...         ...    ...    ...    ...    ...
# 4    1989-12-22  347.4  344.8  347.5  344.8
# 3    1989-12-26  346.8  347.4  347.9  346.5
# 2    1989-12-27  348.8  346.8  349.1  346.8
# 1    1989-12-28  350.7  348.8  350.7  348.8
# 0    1989-12-29  353.4  350.7  353.4  350.7
#
# [2531 rows x 5 columns]

# %%
from sklearn.preprocessing import MinMaxScaler

df.sort_index(ascending=False).reset_index(drop=True)

scaler = MinMaxScaler()
scale_cols = ['종가', '오픈', '고가', '저가']
df_scaled = scaler.fit_transform(df1_1[scale_cols])
df_scaled = pd.DataFrame(df_scaled)
df_scaled.columns = scale_cols

df_scaled
# Out:
#             종가        오픈        고가        저가
# 0     0.037080  0.037080  0.031825  0.051914
# 1     0.029052  0.029052  0.033742  0.042061
# 2     0.026758  0.026758  0.024923  0.034483
# 3     0.031728  0.031728  0.028758  0.041304
# 4     0.032875  0.032875  0.031442  0.043956
# ...        ...       ...       ...       ...
# 2526  0.952599  0.942661  0.950537  0.949602
# 2527  0.950306  0.952599  0.952071  0.956044
# 2528  0.957951  0.950306  0.956672  0.957181
# 2529  0.965214  0.957951  0.962807  0.964759
# 2530  0.975535  0.965214  0.973160  0.971959
#
# [2531 rows x 4 columns]

# %%
TEST_SIZE = 200
WINDOW_SIZE = 20

train = df_scaled[:-TEST_SIZE]
test = df_scaled[-TEST_SIZE:]

# %%
def make_dataset(data, label, window_size=20):
    feature_list = []
    label_list = []
    for i in range(len(data) - window_size):
        feature_list.append(np.array(data.iloc[i:i+window_size]))
        label_list.append(np.array(label.iloc[i+window_size]))
    return np.array(feature_list), np.array(label_list)

# %%
from sklearn.model_selection import train_test_split

feature_cols = ['오픈', '고가', '저가']
label_cols = ['종가']

train_feature = train[feature_cols]
train_label = train[label_cols]

train_feature, train_label = make_dataset(train_feature, train_label, 20)

x_train, x_valid, y_train, y_valid = train_test_split(train_feature, train_label, test_size=0.2)
x_train.shape, x_valid.shape
# Out:
# ((1848, 20, 3), (463, 20, 3))

# %%
test_feature = test[feature_cols]
test_label = test[label_cols]

test_feature.shape, test_label.shape
# Out:
# ((200, 3), (200, 1))

# %%
test_feature, test_label = make_dataset(test_feature, test_label, 20)
test_feature.shape, test_label.shape
# Out:
# ((180, 20, 3), (180, 1))

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.layers import LSTM

model = Sequential()
model.add(LSTM(16, 
               input_shape=(train_feature.shape[1], train_feature.shape[2]), 
               activation='relu', 
               return_sequences=False)
          )

model.add(Dense(1))
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (1.26.7) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "

# %%
import os

model.compile(loss='mean_squared_error', optimizer='adam')
early_stop = EarlyStopping(monitor='val_loss', patience=5)

model_path = 'model'
filename = os.path.join(model_path, 'tmp_checkpoint.h5')
checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

history = model.fit(x_train, y_train, 
                                    epochs=200, 
                                    batch_size=16,
                                    validation_data=(x_valid, y_valid), 
                                    callbacks=[early_stop, checkpoint])
# Out:
# Epoch 1/200
# 116/116 [==============================] - 21s 10ms/step - loss: 0.0069 - val_loss: 2.1906e-04
#
# Epoch 00001: val_loss improved from inf to 0.00022, saving model to model/tmp_checkpoint.h5
# Epoch 2/200
# 116/116 [==============================] - 1s 5ms/step - loss: 3.2256e-04 - val_loss: 2.6314e-04
#
# Epoch 00002: val_loss did not improve from 0.00022
# Epoch 3/200
# 116/116 [==============================] - 1s 4ms/step - loss: 3.5857e-04 - val_loss: 1.8528e-04
#
# Epoch 00003: val_loss improved from 0.00022 to 0.00019, saving model to model/tmp_checkpoint.h5
# Epoch 4/200
# 116/116 [==============================] - 1s 4ms/step - loss: 3.1843e-04 - val_loss: 3.3478e-04
#
# Epoch 00004: val_loss did not improve from 0.00019
# Epoch 5/200
# 116/116 [==============================] - 0s 4ms/step - loss: 2.7664e-04 - val_loss: 2.3133e-04
#
# Epoch 00005: val_loss did not improve from 0.00019
# Epoch 6/200
# ...

# %%
model.load_weights(filename)
pred = model.predict(test_feature)

pred.shape
plt.figure(figsize=(12, 9))
plt.plot(test_label, label = 'actual')
plt.plot(pred, label = 'prediction')
plt.legend()
plt.show()

# %%
df3 = pd.read_csv("/Users/tina/Desktop/기계/S&P/3번데이터.csv")

# %%
plt.figure(figsize=(16, 9))
sns.lineplot(y=df4['변동 %'], x=df4['날짜'])
plt.xlabel('time')
plt.ylabel('price')
# Out:
# Text(0, 0.5, 'price')

# %%
pred
# Out:
# array([[0.76669556],
#        [0.7747639 ],
#        [0.7814352 ],
#        [0.79211915],
#        [0.79680175],
#        [0.799902  ],
#        [0.80556774],
#        [0.80574495],
#        [0.8018101 ],
#        [0.8027037 ],
#        [0.8062538 ],
#        [0.80670875],
#        [0.80735105],
#        [0.80443716],
#        [0.8035256 ],
#        [0.80373734],
#        [0.7996146 ],
#        [0.795597  ],
#        [0.79336554],
#        [0.79456556],
#        [0.8008416 ],
#        [0.8171982 ],
#        [0.8271622 ],
#        [0.83136266],
#        [0.8365556 ],
#        [0.8417018 ],
#        [0.8495607 ],
#        [0.85043806],
#        [0.8443151 ],
#        [0.8436141 ],
#        [0.8449023 ],
#        [0.8470511 ],
#        [0.84499437],
#        [0.8474896 ],
#        [0.85329103],
#        [0.8591103 ],
#        [0.8559908 ],
#        [0.86127   ],
#        [0.867173  ],
#        [0.8685579 ],
#        [0.8672028 ],
#        [0.86504674],
#        [0.86058944],
# ...
